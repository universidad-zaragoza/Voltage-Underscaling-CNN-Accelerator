# %%
import os
import pickle as pickle
import tensorflow as tf
import numpy as np
from Stats_original import WeightQuantization,IntroduceFaultsInWeights,GenerateFaultsList,CheckAccuracyAndLoss
#from Nets_original import GetNeuralNetworkModel
from Nets import GetNeuralNetworkModel
from Training import GetDatasets
from Simulation import get_all_outputs
from Simulation import buffer_simulation, save_obj, load_obj
from datetime import datetime
import collections 
import pandas as pd
import os, sys
import pathlib
print(tf.__version__)
# Out:
# 2.5.0

# %%
#locs  = load_obj('Data/Fault Characterization/error_mask_0/vc_707/locs_060')
#error_mask = load_obj('Data/Fault Characterization/error_mask_0/vc_707/error_mask_060')

ruta_bin = 'Data/Fault Characterization/error_mask_0/vc_707'
#ruta_bin = 'Data/Fault Characterization/KC705_B/RowData/'
directorio = pathlib.Path(ruta_bin)

ficheros = [fichero.name for fichero in directorio.iterdir()]

ficheros.sort()

vol=54
for i in range(7):
    
    error_mask=load_obj('Data/Fault Characterization/error_mask_0/vc_707/error_mask_0'+str(vol))
    locs  = load_obj('Data/Fault Characterization/error_mask_0/vc_707/locs_0'+ str(vol))
    vol=vol+1
    print(i)
    print(vol)
    print(len(locs))
    print(error_mask)
# Out:
# 0
# 55
# 4738
# ['0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', ...
# 1
# 56
# 1599
# ['0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', ...
# 2
# 57
# 564
# ['0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', ...
# 3
# 58
# 169
# ['0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000']
# 4
# 59
# 28
# ['0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000', '0000000000000000']
# 5
# 60
# 3
# ['0000000000000000', '0000000000000000', '0000000000000000']
# 6
# 61
# 1
# ['0000000000000000']

# %%
locs  = load_obj('Data/Fault Characterization/error_mask y locs_buffer_act_vc-707/locs_054')
error_mask = load_obj('Data/Fault Characterization/error_mask y locs_buffer_act_vc-707/error_mask_054')

# %% [markdown]
# # AlexNet

# %%
cwd = os.getcwd()
wgt_dir = os.path.join(cwd, 'Data')
wgt_dir = os.path.join(wgt_dir, 'Trained Weights')
wgt_dir = os.path.join(wgt_dir, 'AlexNet')
wgt_dir = os.path.join(wgt_dir, 'Colorectal Dataset')
wgt_dir = os.path.join(wgt_dir,'Weights')

Accs_A=[]

trainBatchSize = testBatchSize = 10
_,_,test_dataset = GetDatasets('colorectal_histology',(80,5,15),(227,227), 8, trainBatchSize, testBatchSize)




loss,acc   = CheckAccuracyAndLoss('AlexNet', test_dataset, wgt_dir, output_shape=8, input_shape = (227,227,3),
                                            act_frac_size = 11, act_int_size = 4, wgt_frac_size = 11, wgt_int_size = 4,
                                            batch_size=testBatchSize, verbose = 0, aging_active = True, weights_faults = False,
                                            faulty_addresses = locs, masked_faults = error_mask)

Accs_A.append(acc)
Acc_AlexNet=pd.DataFrame(Accs_A)
# Out:
# C:\Users\usuario\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:3703: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable.debug_mode()`.
#   warnings.warn(
# faults[:,0] Tensor("lambda_5/strided_slice_1:0", shape=(5280,), dtype=int32)
# valores_afectados Tensor("lambda_5/NotEqual:0", shape=(5280,), dtype=bool)
# valores afectados por los errores Tensor("lambda_5/GatherNd_1:0", shape=(None,), dtype=int32)
# valores que se deberian escribir Tensor("lambda_5/GatherNd_2:0", shape=(None,), dtype=int32)
# mask_0 Tensor("lambda_5/Const_1:0", shape=(), dtype=int32)
# b Vm>Vb Tensor("lambda_5/Greater:0", shape=(None,), dtype=bool)
# c Tensor("lambda_5/Where_6:0", shape=(None, 1), dtype=int64)
# tamaño de c Tensor("lambda_5/Size:0", shape=(), dtype=int32)
#  c Indices de los valores a transformar a 0 Tensor("lambda_5/Where_6:0", shape=(None, 1), dtype=int64)
# cnumpy Tensor("lambda_5/Identity:0", shape=(None, 1), dtype=int64)
# index_values_error_a_0 Tensor("lambda_5/Where_8:0", shape=(None, 1), dtype=int64)
# index_0 Tensor("lambda_5/Identity_1:0", shape=(None, 1), dtype=int64)
# valores_afectados Tensor("lambda_5/NotEqual:0", shape=(5280,), dtype=bool)
# val_0 Tensor("lambda_5/GatherNd_8:0", shape=(None, 1), dtype=int64)
# tensor_act Tensor("lambda_5/TensorScatterUpdate_1:0", shape=(5280,), dtype=int32)
# valores_afectados Tensor("lambda_5/NotEqual:0", shape=(5280,), dtype=bool)
# tensor_with_error Tensor("lambda_5/BitwiseOr:0", shape=(5280,), dtype=int32)
# v_b Tensor("lambda_5/GatherNd_2:0", shape=(None,), dtype=int32)
# v_m Tensor("lambda_5/GatherNd_1:0", shape=(None,), dtype=int32)
# dentro del body
# ---------------------------------------------------------------------------
# OperatorNotAllowedInGraphError            Traceback (most recent call last)
# Input In [9], in <cell line: 16>()
#      10 trainBatchSize = testBatchSize = 10
#      11 _,_,test_dataset = GetDatasets('colorectal_histology',(80,5,15),(227,227), 8, trainBatchSize, testBatchSize)
# ---> 16 loss,acc   = CheckAccuracyAndLoss('AlexNet', test_dataset, wgt_dir, output_shape=8, input_shape = (227,227,3),
#      17                                             act_frac_size = 11, act_int_size = 4, wgt_frac_size = 11, wgt_int_size = 4,
#      18                                             batch_size=testBatchSize, verbose = 0, aging_active = True, weights_faults = False,
#      19                                             faulty_addresses = locs, masked_faults = error_mask)
#      21 Accs_A.append(acc)
#      22 Acc_AlexNet=pd.DataFrame(Accs_A)
#
# File ~\Desktop\CNN_Gating\Stats_original.py:97, in CheckAccuracyAndLoss(architecture, test_dataset, wgt_dir, act_frac_size, act_int_size, wgt_frac_size, wgt_int_size, input_shape, output_shape, faulty_addresses, masked_faults, aging_active, batch_size, verbose, weights_faults)
#      95 def CheckAccuracyAndLoss(architecture, test_dataset, wgt_dir, act_frac_size, act_int_size, wgt_frac_size, wgt_int_size, input_shape, output_shape,
#      96 						 faulty_addresses = [], masked_faults = [], aging_active = False, batch_size = 1, verbose = 1, weights_faults = False):
# ---> 97 	qNet = GetNeuralNetworkModel(architecture,input_shape,output_shape,faulty_addresses,masked_faults,aging_active=aging_active,
#      98 								 word_size=(1+act_frac_size+act_int_size), frac_size=act_frac_size, batch_size = batch_size)
#      99 	#Load Weights
#     100 	qNet.load_weights(wgt_dir).expect_partial()
#
# File ~\Desktop\CNN_Gating\Nets.py:155, in GetNeuralNetworkModel(architecture, input_shape, output_shape, faulty_addresses, masked_faults, quantization, aging_active, word_size, frac_size, batch_size)
#     153 if architecture=='AlexNet':
#     154 	input_layer = tf.keras.Input(input_shape)
# --> 155 	x = AddCustomLayers(input_layer,include_aging=True,aging_active = aging_active[0])
#     156 	x = Conv2D(filters=96, kernel_size=(11,11), strides=(4,4),name='Conv1')(x)
#     157 	x = AddCustomLayers(x,include_aging=False)
#
# File ~\Desktop\CNN_Gating\Nets.py:148, in GetNeuralNetworkModel.<locals>.AddCustomLayers(input_layer, include_aging, include_quantization, aging_active)
#     144 	index_list,mod_list,faults_count = GenerateAddressList(shape=x.shape[1:])
#     145 	aging_arguments = {'index_list' : tf.identity(index_list),
#     146 	                   'mod_list' : tf.identity(mod_list),
#     147 		               'active': tf.identity(faults_count and aging_active)}
# --> 148 	x = Lambda(Aging, arguments = aging_arguments)(x)
#     149 return x
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:969, in Layer.__call__(self, *args, **kwargs)
#     963 # Functional Model construction mode is invoked when `Layer`s are called on
#     964 # symbolic `KerasTensor`s, i.e.:
#     965 # >> inputs = tf.keras.Input(10)
#     966 # >> outputs = MyLayer()(inputs)  # Functional construction mode.
#     967 # >> model = tf.keras.Model(inputs, outputs)
#     968 if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
# --> 969   return self._functional_construction_call(inputs, args, kwargs,
#     970                                             input_list)
#     972 # Maintains info about the `Layer.call` stack.
#     973 call_context = base_layer_utils.call_context()
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:1107, in Layer._functional_construction_call(self, inputs, args, kwargs, input_list)
#    1102     training_arg_passed_by_framework = True
#    1104 with call_context.enter(
#    1105     layer=self, inputs=inputs, build_graph=True, training=training_value):
#    1106   # Check input assumptions set after layer building, e.g. input shape.
# -> 1107   outputs = self._keras_tensor_symbolic_call(
#    1108       inputs, input_masks, args, kwargs)
#    1110   if outputs is None:
#    1111     raise ValueError('A layer\'s `call` method should return a '
#    1112                      'Tensor or a list of Tensors, not None '
#    1113                      '(layer: ' + self.name + ').')
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:840, in Layer._keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     838   return nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     839 else:
# --> 840   return self._infer_output_signature(inputs, args, kwargs, input_masks)
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:880, in Layer._infer_output_signature(self, inputs, args, kwargs, input_masks)
#     878     self._maybe_build(inputs)
#     879     inputs = self._maybe_cast_inputs(inputs)
# --> 880     outputs = call_fn(inputs, *args, **kwargs)
#     882   self._handle_activity_regularization(inputs, outputs)
#     883 self._set_mask_metadata(inputs, outputs, input_masks,
#     884                         build_graph=False)
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\keras\layers\core.py:919, in Lambda.call(self, inputs, mask, training)
#     915   return var
#     917 with backprop.GradientTape(watch_accessed_variables=True) as tape,\
#     918     variable_scope.variable_creator_scope(_variable_creator):
# --> 919   result = self.function(inputs, **kwargs)
#     920 self._check_variables(created_variables, tape.watched_variables())
#     921 return result
#
# File ~\Desktop\CNN_Gating\Nets.py:82, in GetNeuralNetworkModel.<locals>.Aging(tensor, index_list, mod_list, active)
#      80 if active:
#      81 	affectedValues = tf.gather_nd(tensor,index_list)
# ---> 82 	newValues = ApplyFault(affectedValues,mod_list)
#      83 	tensor = tf.tensor_scatter_nd_update(tensor, index_list, newValues)
#      84 return tensor
#
# File ~\Desktop\CNN_Gating\Nets.py:74, in GetNeuralNetworkModel.<locals>.Aging.<locals>.ApplyFault(tensor, faults)
#      72 tensor  = tf.cast(tensor*factor,dtype=tf.int32)
#      73 tensor  = tf.where(tf.less(tensor, 0), -tensor + shift , tensor )
# ---> 74 tensor = FuncionRound(tensor, faults)
#      75 tensor  = tf.bitwise.bitwise_and(tensor,faults[:,0])
#      76 tensor  = tf.bitwise.bitwise_or(tensor,faults[:,1])
#
# File ~\Desktop\CNN_Gating\FuncionRoundTensor.py:311, in FuncionRound(tensor, faults)
#     307             print('i', i)
#     309             return (i + 1), out, mask, mask_0, tensor, tensor_act, v_m, v_b, tensor_with_error, values_to_run, valores_afectados, valores_afec_static_0_Error, valores_afec_static_1_Error  ## retorno los valores que aun no se han modificado por ninguna d elas variantes puesto que el bit con error
# --> 311 i, out, mask, mask_0, tensor, tensor_act, v_m, v_b, tensor_with_error, values_to_run, valores_afectados, valores_afec_static_0_Error, valores_afec_static_1_Error = tf.while_loop(
#     312 lambda i, *_: tf.less(i, out),  # condición -> revisar cada bit
#     313 while_body,  # aqui
#     314         # o pasarlos a la misma función de while_body y no modificarlos)
#     315 (i, out, mask, mask_0, tensor, tensor_act, v_m, v_b, tensor_with_error, values_to_run, valores_afectados,  valores_afec_static_0_Error, valores_afec_static_1_Error)  # valores iniciales
#     316 )
#     318 return tensor_act
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\util\deprecation.py:602, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     595           _PRINTED_WARNING[(func, arg_name)] = True
#     596         logging.warning(
#     597             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     598             'will be removed %s.\nInstructions for updating:\n%s',
#     599             _call_location(), decorator_utils.get_qualified_name(func),
#     600             func.__module__, arg_name, arg_value, 'in a future version'
#     601             if date is None else ('after %s' % date), instructions)
# --> 602 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\ops\control_flow_ops.py:2531, in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#    2355 @tf_export("while_loop", v1=[])
#    2356 @deprecation.deprecated_arg_values(
#    2357     None,
#    (...)
#    2372                   maximum_iterations=None,
#    2373                   name=None):
#    2374   """Repeat `body` while the condition `cond` is true.
#    2375
#    2376   `cond` is a callable returning a boolean scalar tensor. `body` is a callable
#    (...)
#    2529
#    2530   """
# -> 2531   return while_loop(
#    2532       cond=cond,
#    2533       body=body,
#    2534       loop_vars=loop_vars,
#    2535       shape_invariants=shape_invariants,
#    2536       parallel_iterations=parallel_iterations,
#    2537       back_prop=back_prop,
#    2538       swap_memory=swap_memory,
#    2539       name=name,
#    2540       maximum_iterations=maximum_iterations,
#    2541       return_same_structure=True)
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\ops\control_flow_ops.py:2729, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2726 executing_eagerly = context.executing_eagerly()
#    2727 if (util.EnableControlFlowV2(ops.get_default_graph()) and
#    2728     not executing_eagerly):
# -> 2729   return while_v2.while_loop(
#    2730       cond,
#    2731       body,
#    2732       loop_vars,
#    2733       shape_invariants=shape_invariants,
#    2734       parallel_iterations=parallel_iterations,
#    2735       maximum_iterations=maximum_iterations,
#    2736       name=name,
#    2737       return_same_structure=return_same_structure,
#    2738       back_prop=back_prop)
#    2740 with ops.name_scope(name, "while", loop_vars):
#    2741   if not loop_vars:
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\ops\while_v2.py:194, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, maximum_iterations, name, return_same_structure, back_prop)
#     190   # TODO(srbs): Update lowering code to create _Enter nodes with
#     191   # is_constant=True for inputs that are directly passed to outputs.
#     192   return [loop_counter + 1, maximum_iterations_arg] + list(outputs)
# --> 194 body_graph = func_graph_module.func_graph_from_py_func(
#     195     body_name,
#     196     wrapped_body,
#     197     [],  # We provide signature instead of args.
#     198     {},
#     199     signature=signature,
#     200     func_graph=util.WhileBodyFuncGraph(
#     201         body_name, collections=ops.get_default_graph()._collections),  # pylint: disable=protected-access
#     202     add_control_dependencies=add_control_dependencies)
#     203 # Add external captures of body to the list of loop vars.
#     204 # Note that external tensors will be treated as loop invariants, i.e.,
#     205 # the value of that tensor in each iteration is the same as it was at the
#     206 # beginning of the loop execution.
#     207 loop_vars = loop_vars + body_graph.external_captures
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\framework\func_graph.py:999, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     996 else:
#     997   _, original_func = tf_decorator.unwrap(python_func)
# --> 999 func_outputs = python_func(*func_args, **func_kwargs)
#    1001 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1002 # TensorArrays and `None`s.
#    1003 func_outputs = nest.map_structure(convert, func_outputs,
#    1004                                   expand_composites=True)
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\ops\while_v2.py:180, in while_loop.<locals>.wrapped_body(loop_counter, maximum_iterations_arg, *args)
#     173   ops.get_default_graph().capture(t)
#     175 # Convert the flow variables in `args` to TensorArrays. `args` should
#     176 # already have the same structure as `orig_loop_vars` but currently there
#     177 # is no nest.zip so we call `_pack_sequence_as` which flattens both
#     178 # `orig_loop_vars` and `args`, converts flows in `args` to TensorArrays
#     179 # and packs it into the structure of `orig_loop_vars`.
# --> 180 outputs = body(*_pack_sequence_as(orig_loop_vars, args))
#     181 if not nest.is_sequence_or_composite(outputs):
#     182   outputs = [outputs]
#
# File ~\Desktop\CNN_Gating\FuncionRoundTensor.py:228, in FuncionRound.<locals>.while_body(i, out, mask, mask_0, tensor, tensor_act, v_m, v_b, tensor_with_error, values_to_run, valores_afectados, valores_afec_static_0_Error, valores_afec_static_1_Error)
#     207 print('dentro del body')
#     209 #     print('i',i)
#     210 #     print('out que llega al body', out)
#     211 #      print('tensor_act',tensor_act)
#    (...)
#     226 #@tf.function
#     227 #def Condicional(mask_0,v_b,v_m,mask,valores_afectados,valores_afec_static_0_Error,valores_afec_static_1_Error,tensor_act):
# --> 228 if tf.reduce_sum(mask_0) > 0:
#     229         # print('entre en condicion mask_0>0')
#     230         # print('valores donde debo correr el mask')
#     232     vb_and_mask = tf.bitwise.bitwise_and(v_b, mask)
#     233     print('vb_and_mask', vb_and_mask)
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\framework\ops.py:900, in Tensor.__bool__(self)
#     882 def __bool__(self):
#     883   """Dummy method to prevent a tensor from being used as a Python `bool`.
#     884
#     885   This overload raises a `TypeError` when the user inadvertently
#    (...)
#     898     `TypeError`.
#     899   """
# --> 900   self._disallow_bool_casting()
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\framework\ops.py:507, in Tensor._disallow_bool_casting(self)
#     503   self._disallow_when_autograph_enabled(
#     504       "using a `tf.Tensor` as a Python `bool`")
#     505 else:
#     506   # Default: V1-style Graph execution.
# --> 507   self._disallow_in_graph_mode("using a `tf.Tensor` as a Python `bool`")
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\framework\ops.py:494, in Tensor._disallow_in_graph_mode(self, task)
#     493 def _disallow_in_graph_mode(self, task):
# --> 494   raise errors.OperatorNotAllowedInGraphError(
#     495       "{} is not allowed in Graph execution. Use Eager execution or decorate"
#     496       " this function with @tf.function.".format(task))
#
# OperatorNotAllowedInGraphError: using a `tf.Tensor` as a Python `bool` is not allowed in Graph execution. Use Eager execution or decorate this function with @tf.function.

# %%
Accs_A
# Out:
# [0.890666663646698]

# %% [markdown]
# # SqueezeNet

# %%
# Directorio de los pesos
    cwd = os.getcwd()
    wgt_dir = os.path.join(cwd, 'Data')
    wgt_dir = os.path.join(wgt_dir, 'Trained Weights')
    wgt_dir = os.path.join(wgt_dir, 'SqueezeNet')
    wgt_dir = os.path.join(wgt_dir, 'Colorectal Dataset')
    wgt_dir = os.path.join(wgt_dir,'Weights')
    Accs_S=[]
    
    
    trainBatchSize = testBatchSize = 10
    _,_,test_dataset = GetDatasets('colorectal_histology',(80,5,15),(224,224), 8, trainBatchSize, testBatchSize)
    
    loss,acc   = CheckAccuracyAndLoss('SqueezeNet', test_dataset, wgt_dir, output_shape=8, input_shape = (224,224,3),
                                                act_frac_size = 9, act_int_size = 6, wgt_frac_size = 15, wgt_int_size = 0,
                                                batch_size=testBatchSize, verbose = 0, aging_active = True, weights_faults = False,
                                                faulty_addresses = locs, masked_faults = error_mask)
    
    Accs_S.append(acc)
Acc_SqueezeNet=pd.DataFrame(Accs_S)
# Out:
#   Input In [7]
#     cwd = os.getcwd()
#     ^
# IndentationError: unexpected indent

# %%
Acc_SqueezeNet
# Out:
#           0
# 0  0.897333
# 1  0.802667

# %% [markdown]
# # DenseNet

# %%
# Directorio de los pesos
    cwd = os.getcwd()
    wgt_dir = os.path.join(cwd, 'Data')
    wgt_dir = os.path.join(wgt_dir, 'Trained Weights')
    wgt_dir = os.path.join(wgt_dir, 'DenseNet')
    wgt_dir = os.path.join(wgt_dir, 'Colorectal Dataset')
    wgt_dir = os.path.join(wgt_dir,'Weights')
    
    Accs_D=[]
    
    trainBatchSize = testBatchSize = 10
    _,_,test_dataset = GetDatasets('colorectal_histology',(80,5,15),(224,224), 8, trainBatchSize, testBatchSize)
    
    loss,acc   = CheckAccuracyAndLoss('DenseNet', test_dataset, wgt_dir, output_shape=8, input_shape = (224,224,3),
                                                act_frac_size = 12, act_int_size = 3, wgt_frac_size = 13, wgt_int_size = 2,
                                                batch_size=testBatchSize, verbose = 0, aging_active = True, weights_faults = False,
                                                faulty_addresses = locs, masked_faults = error_mask)
        
    Accs_D.append(acc)
Acc_DenseNet=pd.DataFrame(Accs_D)

# %%
acc
# Out:
# 0.8426666855812073

# %% [markdown]
# # MobileNet

# %%
# Directorio de los pesos
    cwd = os.getcwd()
    wgt_dir = os.path.join(cwd, 'Data')
    wgt_dir = os.path.join(wgt_dir, 'Trained Weights')
    wgt_dir = os.path.join(wgt_dir, 'MobileNet')
    wgt_dir = os.path.join(wgt_dir, 'Colorectal Dataset')
    wgt_dir = os.path.join(wgt_dir,'Weights')
    Accs_M=[]
    
    
    trainBatchSize = testBatchSize = 10
    _,_,test_dataset = GetDatasets('colorectal_histology',(80,5,15),(224,224), 8, trainBatchSize, testBatchSize)
    
    
    loss,acc   = CheckAccuracyAndLoss('MobileNet', test_dataset, wgt_dir, output_shape=8, input_shape = (224,224,3),
                                                act_frac_size = 11, act_int_size = 4, wgt_frac_size = 14, wgt_int_size = 1,
                                                batch_size=testBatchSize, verbose = 0, aging_active = True, weights_faults = False,
                                                faulty_addresses = locs, masked_faults = error_mask)
    Accs_M.append(acc)
Acc_MobileNet=pd.DataFrame(Accs_M)

# %%
Acc_MobileNet
# Out:
#           0
# 0  0.897333
# 1  0.802667
# 2  0.842667
# 3  0.457333

# %% [markdown]
# # VGG16

# %%
# Directorio de los pesos
    cwd = os.getcwd()
    wgt_dir = os.path.join(cwd, 'Data')
    wgt_dir = os.path.join(wgt_dir, 'Trained Weights')
    wgt_dir = os.path.join(wgt_dir, 'VGG16')
    wgt_dir = os.path.join(wgt_dir, 'Colorectal Dataset')
    wgt_dir = os.path.join(wgt_dir,'Weights')
    
    Accs_V=[]
    
    trainBatchSize = testBatchSize = 10
    _,_,test_dataset = GetDatasets('colorectal_histology',(80,5,15),(224,224), 8, trainBatchSize, testBatchSize)
    
    
    loss,acc   = CheckAccuracyAndLoss('VGG16', test_dataset, wgt_dir, output_shape=8, input_shape = (224,224,3),
                                                act_frac_size = 12, act_int_size = 3, wgt_frac_size = 15, wgt_int_size = 0,
                                                batch_size=testBatchSize, verbose = 0, aging_active = True, weights_faults = False,
                                                faulty_addresses = locs, masked_faults = error_mask)
    
    Accs_V.append(acc)
Acc_VGG16=pd.DataFrame(Accs_V)

# %% [markdown]
# # ZFNet

# %%
# Directorio de los pesos
    cwd = os.getcwd()
    wgt_dir = os.path.join(cwd, 'Data')
    wgt_dir = os.path.join(wgt_dir, 'Trained Weights')
    wgt_dir = os.path.join(wgt_dir, 'ZFNet')
    wgt_dir = os.path.join(wgt_dir, 'Colorectal Dataset')
    wgt_dir = os.path.join(wgt_dir,'Weights')
    
    Accs_Z=[]
    
    trainBatchSize = testBatchSize = 10
    _,_,test_dataset = GetDatasets('colorectal_histology',(80,5,15),(224,224), 8, trainBatchSize, testBatchSize)
    
    loss,acc   = CheckAccuracyAndLoss('ZFNet', test_dataset, wgt_dir, output_shape=8, input_shape = (224,224,3),
                                                act_frac_size = 11, act_int_size = 4, wgt_frac_size = 15, wgt_int_size = 0,
                                                batch_size=testBatchSize, verbose = 0, aging_active = True, weights_faults = False,
                                                faulty_addresses = locs, masked_faults = error_mask)
    
    Accs_Z.append(acc)
Acc_ZFNet=pd.DataFrame(Accs_Z)

# %% [markdown]
# # PilotNet

# %%
    cwd = os.getcwd()
    wgt_dir = os.path.join(cwd, 'Data')
    wgt_dir = os.path.join(wgt_dir, 'Trained Weights')
    wgt_dir = os.path.join(wgt_dir, 'PilotNet')
    wgt_dir = os.path.join(wgt_dir,'Weights')
    PilotNet.load_weights(wgt_dir)
    
    Accs_P=[]
    
    trainBatchSize = testBatchSize = 10
    _,_,test_dataset = GetPilotNetDataset(csv_dir='Data/Datos/driving_log.csv', train_batch_size=32, test_batch_size=32)
    
    acc,loss   = CheckAccuracyAndLoss('PilotNet', test_dataset, wgt_dir, output_shape=1,  input_shape = (160,320,3),
                                                act_frac_size = 15, act_int_size = 0, wgt_frac_size = 15, wgt_int_size = 0,
                                                batch_size=testBatchSize, verbose = 0, aging_active = activation_aging, weights_faults = False,
                                                faulty_addresses = locs, masked_faults = error_mask)
    Accs_P.append(loss)
Acc_PilotNet=pd.DataFrame(Accs_P)
