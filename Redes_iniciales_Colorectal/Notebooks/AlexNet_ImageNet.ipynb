# %%
# %load_ext autoreload
# %autoreload 2

import tensorflow as tf
import tensorflow_datasets as tfds
import os
import sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from Training_imagenette import GetDatasets
from Nets_original  import GetNeuralNetworkModel
from Stats import WeightQuantization, ActivationStats, CheckAccuracyAndLoss, QuantizationEffect, GetReadAndWrites
from FileAnalize import analize_file, analize_file_uno,analize_file_uno_ceros, save_file, load_file
from funciones import buffer_vectores
from datetime import datetime
import itertools
import pathlib
import os, sys
#from openpyxl import Workbook
#from openpyxl import load_workbook
from Simulation import buffer_simulation, save_obj, load_obj

tf.random.set_seed(1234)
np.random.seed(1234)

# %% [markdown]
# # 1) Training

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; a) Get Dataset

# %% [markdown]
# Primero Obtendremos el dataset colorectal, especificando la distribucion de entrenamiento/validacion y testing (80%,5%,15% para este caso); las dimensiones de entrada de la imagen (227,227), el numero de clases (8) y el tamaño de los batches.
# Nota: Pueden aparecer un monton de mensajes de tensorflow durante la primera ejecucion, no impactan en nada

# %%
ds=tfds.load('imagenette/320px', split=['train','validation'], shuffle_files=True)

# %%
tfds.load('imagenette')
# Out:
# C:\Users\usuario\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:3703: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable.debug_mode()`.
#   warnings.warn(
# {'train': <PrefetchDataset shapes: {image: (None, None, 3), label: ()}, types: {image: tf.uint8, label: tf.int64}>,
#  'validation': <PrefetchDataset shapes: {image: (None, None, 3), label: ()}, types: {image: tf.uint8, label: tf.int64}>}

# %%
tf.data.experimental.enable_debug_mode()
trainBatchSize = testBatchSize = 1
_,_,test_dataset = GetDatasets('imagenette',(320,320), 10, trainBatchSize, testBatchSize)
# Out:
# <class 'list'>
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       1 tf.data.experimental.enable_debug_mode()
#       2 trainBatchSize = testBatchSize = 1
# ----> 3 _,_,test_dataset = GetDatasets('imagenette',(320,320), 10, trainBatchSize, testBatchSize)
#
# File ~\Desktop\CNN_Gating\Training_imagenette.py:106, in GetDatasets(dataset_name, data_shape, target_shape, train_batch_size, test_batch_size, return_size)
#     100 	return image, label
#     101 # def normalize(x_, y_):
#     102 # 	return tf.cast(x_, tf.float32) / 255., y_
#     103 # def resize(image, label):
#     104 # 	image = tf.image.resize(image, (data_shape[0],data_shape[1]))
#     105 # 	return image, label
# --> 106 train_dataset = tf.data.Dataset.from_tensor_slices((x_train,y_train))
#     107 train_dataset = train_dataset.shuffle(buffer_size=x_train.shape[0])
#     109 train_dataset = train_dataset.map(to_categorical)
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:760, in DatasetV2.from_tensor_slices(tensors)
#     683 @staticmethod
#     684 def from_tensor_slices(tensors):
#     685   """Creates a `Dataset` whose elements are slices of the given tensors.
#     686
#     687   The given tensors are sliced along their first dimension. This operation
#    (...)
#     758     Dataset: A `Dataset`.
#     759   """
# --> 760   return TensorSliceDataset(tensors)
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:3320, in TensorSliceDataset.__init__(self, element)
#    3318 def __init__(self, element):
#    3319   """See `Dataset.from_tensor_slices()` for details."""
# -> 3320   element = structure.normalize_element(element)
#    3321   batched_spec = structure.type_spec_from_value(element)
#    3322   self._tensors = structure.to_batched_tensor_list(batched_spec, element)
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\data\util\structure.py:129, in normalize_element(element, element_signature)
#     126       else:
#     127         dtype = getattr(spec, "dtype", None)
#     128         normalized_components.append(
# --> 129             ops.convert_to_tensor(t, name="component_%d" % i, dtype=dtype))
#     130 return nest.pack_sequence_as(pack_as, normalized_components)
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\profiler\trace.py:163, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     161   with Trace(trace_name, **trace_kwargs):
#     162     return func(*args, **kwargs)
# --> 163 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\framework\ops.py:1566, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1561       raise TypeError("convert_to_tensor did not convert to "
#    1562                       "the preferred dtype: %s vs %s " %
#    1563                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#    1565 if ret is None:
# -> 1566   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1568 if ret is NotImplemented:
#    1569   continue
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\ops\array_ops.py:1536, in _autopacking_conversion_function(v, dtype, name, as_ref)
#    1534 elif dtype != inferred_dtype:
#    1535   v = nest.map_structure(_cast_nested_seqs_to_dtype(dtype), v)
# -> 1536 return _autopacking_helper(v, dtype, name or "packed")
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\ops\array_ops.py:1442, in _autopacking_helper(list_or_tuple, dtype, name)
#    1438 if context.executing_eagerly():
#    1439   # NOTE: Fast path when all the items are tensors, this doesn't do any type
#    1440   # checking.
#    1441   if all(isinstance(elem, core.Tensor) for elem in list_or_tuple):
# -> 1442     return gen_array_ops.pack(list_or_tuple, name=name)
#    1443 must_pack = False
#    1444 converted_elems = []
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:6399, in pack(values, axis, name)
#    6397   return _result
#    6398 except _core._NotOkStatusException as e:
# -> 6399   _ops.raise_from_not_ok_status(e, name)
#    6400 except _core._FallbackException:
#    6401   pass
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\framework\ops.py:6897, in raise_from_not_ok_status(e, name)
#    6895 message = e.message + (" name: " + name if name is not None else "")
#    6896 # pylint: disable=protected-access
# -> 6897 six.raise_from(core._status_to_exception(e.code, message), None)
#
# File <string>:3, in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[9469,500,375,3] and type uint8 on /job:localhost/replica:0/task:0/device:CPU:0 by allocator mklcpu [Op:Pack] name: component_0

# %% [markdown]
# El resultado son datasets iterables como el siguiente:

# %%
train_set
# Out:
# <RepeatDataset shapes: ((None, 227, 227, 3), (None, 8)), types: (tf.float32, tf.float32)>

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; b) Get Model

# %% [markdown]
# Luego creamos la red, en principio no activaremos ni la cuantizacion ni el efecto de envejecimiento

# %%
AlexNet   = GetNeuralNetworkModel('AlexNet',(227,227,3),8, quantization = False, aging_active = False)
loss      = tf.keras.losses.CategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
AlexNet.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 AlexNet   = GetNeuralNetworkModel('AlexNet',(227,227,3),8, quantization = False, aging_active = False)
#       2 loss      = tf.keras.losses.CategoricalCrossentropy()
#       3 optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
#
# NameError: name 'GetNeuralNetworkModel' is not defined

# %%
AlexNet.evaluate(test_set)
# Out:
# 75/75 [==============================] - 14s 185ms/step - loss: 2.0814 - accuracy: 0.1160
# [2.081390857696533, 0.11599999666213989]

# %% [markdown]
# con el metodo summary() se puede ver los detalles de la red capa por capa, las capas Lambda emplean la cuantizacion y envejecimiento, las cuales estan presentes pero no activas cuando estas opciones estan desactivadas

# %%
print('Las capas 0,3,9,11,17,19,25,31,37,40,45 y 50  contienen la informacion para su procesamiento')
print('Las capas 2,8,10,16,18,24,30,36,38,44,49 y 53 contienen las activaciones que son escritas en memoria')

# %%
AlexNet.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 227, 227, 3)]     0
# _________________________________________________________________
# lambda (Lambda)              (None, 227, 227, 3)       0
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 227, 227, 3)       0
# _________________________________________________________________
# Conv1 (Conv2D)               (None, 55, 55, 96)        34944
# _________________________________________________________________
# lambda_2 (Lambda)            (None, 55, 55, 96)        0
# _________________________________________________________________
# re_lu (ReLU)                 (None, 55, 55, 96)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 55, 55, 96)        384
# _________________________________________________________________
# lambda_3 (Lambda)            (None, 55, 55, 96)        0
# _________________________________________________________________
# lambda_4 (Lambda)            (None, 55, 55, 96)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 27, 27, 96)        0
# _________________________________________________________________
# lambda_5 (Lambda)            (None, 27, 27, 96)        0
# _________________________________________________________________
# Conv2 (Conv2D)               (None, 27, 27, 256)       614656
# _________________________________________________________________
# lambda_6 (Lambda)            (None, 27, 27, 256)       0
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 27, 27, 256)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 27, 27, 256)       1024
# _________________________________________________________________
# lambda_7 (Lambda)            (None, 27, 27, 256)       0
# _________________________________________________________________
# lambda_8 (Lambda)            (None, 27, 27, 256)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 256)       0
# _________________________________________________________________
# lambda_9 (Lambda)            (None, 13, 13, 256)       0
# _________________________________________________________________
# Conv3 (Conv2D)               (None, 13, 13, 384)       885120
# _________________________________________________________________
# lambda_10 (Lambda)           (None, 13, 13, 384)       0
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 13, 13, 384)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 13, 13, 384)       1536
# _________________________________________________________________
# lambda_11 (Lambda)           (None, 13, 13, 384)       0
# _________________________________________________________________
# lambda_12 (Lambda)           (None, 13, 13, 384)       0
# _________________________________________________________________
# Conv4 (Conv2D)               (None, 13, 13, 384)       147840
# _________________________________________________________________
# lambda_13 (Lambda)           (None, 13, 13, 384)       0
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 13, 13, 384)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 13, 13, 384)       1536
# _________________________________________________________________
# lambda_14 (Lambda)           (None, 13, 13, 384)       0
# _________________________________________________________________
# lambda_15 (Lambda)           (None, 13, 13, 384)       0
# _________________________________________________________________
# Conv5 (Conv2D)               (None, 13, 13, 256)       98560
# _________________________________________________________________
# lambda_16 (Lambda)           (None, 13, 13, 256)       0
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 13, 13, 256)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 13, 13, 256)       1024
# _________________________________________________________________
# lambda_17 (Lambda)           (None, 13, 13, 256)       0
# _________________________________________________________________
# lambda_18 (Lambda)           (None, 13, 13, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# lambda_19 (Lambda)           (None, 6, 6, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              37752832
# _________________________________________________________________
# lambda_20 (Lambda)           (None, 4096)              0
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 4096)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# lambda_21 (Lambda)           (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# lambda_22 (Lambda)           (None, 4096)              0
# _________________________________________________________________
# re_lu_6 (ReLU)               (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# lambda_23 (Lambda)           (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 32776
# _________________________________________________________________
# lambda_24 (Lambda)           (None, 8)                 0
# _________________________________________________________________
# tf.compat.v1.nn.softmax (TFO (None, 8)                 0
# _________________________________________________________________
# lambda_25 (Lambda)           (None, 8)                 0
# =================================================================
# Total params: 56,353,544
# Trainable params: 56,350,792
# Non-trainable params: 2,752
# _________________________________________________________________

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; c) Training

# %% [markdown]
# Si se utilizan pesos ya entrenados el entrenamiento se puede omitir

# %%
# Early Stopping
# --------------
#earlyStop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)
#    
#AlexNet.fit(x=train_set,epochs=100,
#            steps_per_epoch  =int(np.ceil(train_size / train_batch_size)),
#            validation_data  =valid_set,
#            validation_steps =int(np.ceil(valid_size/ train_batch_size)), 
#            callbacks=[earlyStop])

# %% [markdown]
# a continuacion cargamos o guardamos los pesos en la ruta especificada usando el metodo load_weights/save_weights

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; d) Load/Save Weigths

# %%
cwd = os.getcwd()
wgt_dir = os.path.join(cwd, 'Data')
wgt_dir = os.path.join(wgt_dir, 'Trained Weights')
wgt_dir = os.path.join(wgt_dir, 'AlexNet')
wgt_dir = os.path.join(wgt_dir, 'Colorectal Dataset')
wgt_dir = os.path.join(wgt_dir,'Weights')
AlexNet.load_weights(wgt_dir)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py:69, in get_tensor(self, tensor_str)
#      68 try:
# ---> 69   return CheckpointReader.CheckpointReader_GetTensor(
#      70       self, compat.as_bytes(tensor_str))
#      71 # TODO(b/143319754): Remove the RuntimeError casting logic once we resolve the
#      72 # issue with throwing python exceptions from C++.
#
# RuntimeError: NewRandomAccessFile failed to Create/Open: C:\Users\usuario\Desktop\CNN_Gating\Data\Trained Weights\AlexNet\Colorectal Dataset\Weights.data-00000-of-00001 : El sistema no puede encontrar el archivo especificado.
# ; No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# OpError                                   Traceback (most recent call last)
# Input In [4], in <cell line: 7>()
#       5 wgt_dir = os.path.join(wgt_dir, 'Colorectal Dataset')
#       6 wgt_dir = os.path.join(wgt_dir,'Weights')
# ----> 7 AlexNet.load_weights(wgt_dir)
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\keras\engine\training.py:2297, in Model.load_weights(self, filepath, by_name, skip_mismatch, options)
#    2295 filepath, save_format = _detect_save_format(filepath)
#    2296 if save_format == 'tf':
# -> 2297   status = self._trackable_saver.restore(filepath, options)
#    2298   if by_name:
#    2299     raise NotImplementedError(
#    2300         'Weights may only be loaded based on topology into Models when '
#    2301         'loading TensorFlow-formatted weights (got by_name=True to '
#    2302         'load_weights).')
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\training\tracking\util.py:1301, in TrackableSaver.restore(self, save_path, options)
#    1299   dtype_map = reader.get_variable_to_dtype_map()
#    1300 try:
# -> 1301   object_graph_string = reader.get_tensor(base.OBJECT_GRAPH_PROTO_KEY)
#    1302 except errors_impl.NotFoundError:
#    1303   # The object graph proto does not exist in this checkpoint. Try the
#    1304   # name-based compatibility mode.
#    1305   restore_coordinator = _NameBasedRestoreCoordinator(
#    1306       save_path=save_path,
#    1307       dtype_map=dtype_map)
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py:74, in get_tensor(self, tensor_str)
#      71 # TODO(b/143319754): Remove the RuntimeError casting logic once we resolve the
#      72 # issue with throwing python exceptions from C++.
#      73 except RuntimeError as e:
# ---> 74   error_translator(e)
#
# File ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py:48, in error_translator(e)
#      46   raise errors_impl.InternalError(None, None, error_message)
#      47 else:
# ---> 48   raise errors_impl.OpError(None, None, error_message, errors_impl.UNKNOWN)
#
# OpError: NewRandomAccessFile failed to Create/Open: C:\Users\usuario\Desktop\CNN_Gating\Data\Trained Weights\AlexNet\Colorectal Dataset\Weights.data-00000-of-00001 : El sistema no puede encontrar el archivo especificado.
# ; No such file or directory

# %% [markdown]
# podemos evaluar el accuracy y loss de la red

# %%
(OrigLoss,OrigAcc) = AlexNet.evaluate(test_set)
# Out:
# 750/750 [==============================] - 28s 37ms/step - loss: 0.3156 - accuracy: 0.8853

# %% [markdown]
# # 2) Stats

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Write/Read Stats

# %% [markdown]
# primero identificamos (manualmente) las capas procesadadas(Convoluciones, Full conectadas y Pooling) junto a las capas que contienen los resultados que se escribiran en el buffer (capas luego de la funcion de activacion y/o Normalizacion)

# %%
for index,layer in enumerate(AlexNet.layers):
    print(index,layer.name)
print('Las capas 0,3,9,11,17,19,25,31,37,40,45 y 50  contienen la informacion para su procesamiento')
print('Las capas 2,8,10,16,18,24,30,36,38,44,49 y 53 contienen las activaciones que son escritas en memoria')
# Out:
# 0 input_1
# 1 lambda
# 2 lambda_1
# 3 Conv1
# 4 lambda_2
# 5 re_lu
# 6 batch_normalization
# 7 lambda_3
# 8 lambda_4
# 9 max_pooling2d
# 10 lambda_5
# 11 Conv2
# 12 lambda_6
# 13 re_lu_1
# 14 batch_normalization_1
# 15 lambda_7
# 16 lambda_8
# 17 max_pooling2d_1
# 18 lambda_9
# 19 Conv3
# 20 lambda_10
# 21 re_lu_2
# 22 batch_normalization_2
# 23 lambda_11
# 24 lambda_12
# 25 Conv4
# 26 lambda_13
# 27 re_lu_3
# 28 batch_normalization_3
# 29 lambda_14
# 30 lambda_15
# 31 Conv5
# 32 lambda_16
# 33 re_lu_4
# 34 batch_normalization_4
# 35 lambda_17
# 36 lambda_18
# 37 max_pooling2d_2
# 38 lambda_19
# 39 flatten
# 40 dense
# 41 lambda_20
# 42 re_lu_5
# 43 dropout
# 44 lambda_21
# 45 dense_1
# 46 lambda_22
# 47 re_lu_6
# 48 dropout_1
# 49 lambda_23
# 50 dense_2
# 51 lambda_24
# 52 tf.compat.v1.nn.softmax
# 53 lambda_25
# Las capas 0,3,9,11,17,19,25,31,37,40,45 y 50  contienen la informacion para su procesamiento
# Las capas 2,8,10,16,18,24,30,36,38,44,49 y 53 contienen las activaciones que son escritas en memoria

# %% [markdown]
# con el siguiente bloque obtenemos el numero de lecturas y escrituras por posicion de memoria tanto usando la estrategia de CNN Gating o sin usarla

# %%
num_address  = 290400  # Tamaño del buffer, igual a la capa mas grande de la red (este caso), o un tamaño fijo pre-establecido.
Indices      = [0,3,9,11,17,19,25,31,37,40,45,50] #Capas con la informacion de procesamiento 
samples      = 10 #Numero de imagenes
# Sin Power Gating:
Data         = GetReadAndWrites(AlexNet,Indices,num_address,samples,CNN_gating=False)
stats        = {'Lecturas': Data['Reads'],'Escrituras': Data['Writes']}
Baseline_Acceses   = pd.DataFrame(stats).reset_index(drop=False)
# Con Power Gating
Data     = GetReadAndWrites(AlexNet,Indices,num_address,samples,CNN_gating=True)
stats    = {'Lecturas': Data['Reads'],'Escrituras': Data['Writes']}
CNN_gating_Acceses = pd.DataFrame(stats).reset_index(drop=False)
#save_obj(Baseline_Acceses,'Data/Acceses/AlexNet/Colorectal Dataset/Baseline')
#save_obj(CNN_gating_Acceses,'Data/Acceses/AlexNet/CNN_gating_Adj')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       3 samples      = 10 #Numero de imagenes
#       4 # Sin Power Gating:
# ----> 5 Data         = GetReadAndWrites(AlexNet,Indices,num_address,samples,CNN_gating=False)
#       6 stats        = {'Lecturas': Data['Reads'],'Escrituras': Data['Writes']}
#       7 Baseline_Acceses   = pd.DataFrame(stats).reset_index(drop=False)
#
# NameError: name 'GetReadAndWrites' is not defined

# %% [markdown]
# Como resultado tenemos los siguientes dataframes

# %%
Baseline_Acceses
# Out:
#          index  Lecturas  Escrituras
# 0            0    687860          55
# 1            1    687860          55
# 2            2    687860          55
# 3            3    687860          55
# 4            4    687860          55
# ...        ...       ...         ...
# 290395  290395         0           0
# 290396  290396         0           0
# 290397  290397         0           0
# 290398  290398         0           0
# 290399  290399         0           0
#
# [290400 rows x 3 columns]

# %%
Data

# %%
CNN_gating_Acceses
# Out:
#          index  Lecturas  Escrituras
# 0            0    129702          14
# 1            1    129702          14
# 2            2    129702          14
# 3            3    129718          14
# 4            4    129718          14
# ...        ...       ...         ...
# 290395  290395       496           7
# 290396  290396       496           7
# 290397  290397       544           7
# 290398  290398       544           7
# 290399  290399       544           7
#
# [290400 rows x 3 columns]

# %% [markdown]
# # 3) Quantization

# %% [markdown]
# Ahora veremos como afecta la cuantizacion, tanto en pesos como en activaciones a la accuracy y loss

# %%
df = QuantizationEffect('AlexNet',test_set,wgt_dir,(227,227,3),8,test_batch_size)
#save_obj(df,'Data/Quantization/AlexNet/Colorectal Dataset/Quantization')
# Out:
# Activation fraction part
# 0  bits results:  acc:  0.35333332419395447 loss:  nan
# 1  bits results:  acc:  0.2933333218097687 loss:  10.372422218322754
# 2  bits results:  acc:  0.4586666524410248 loss:  6.999029159545898
# 3  bits results:  acc:  0.6466666460037231 loss:  3.6160128116607666
# 4  bits results:  acc:  0.8853333592414856 loss:  0.4703865051269531
# 5  bits results:  acc:  0.8853333592414856 loss:  0.4086773991584778
# 6  bits results:  acc:  0.8880000114440918 loss:  0.33622241020202637
# 7  bits results:  acc:  0.8866666555404663 loss:  0.3257526755332947
# 8  bits results:  acc:  0.8853333592414856 loss:  0.3284532129764557
# 9  bits results:  acc:  0.8840000033378601 loss:  0.31434592604637146
# 10  bits results:  acc:  0.8853333592414856 loss:  0.3158952295780182
# 11  bits results:  acc:  0.8853333592414856 loss:  0.3156990110874176
# 12  bits results:  acc:  0.8853333592414856 loss:  0.3155492842197418
# 13  bits results:  acc:  0.8853333592414856 loss:  0.3156721293926239
# 14  bits results:  acc:  0.8853333592414856 loss:  0.3156175911426544
# Weights fraction part
# 0  bits results:  acc:  0.11733333021402359 loss:  2.0794413089752197
# 1  bits results:  acc:  0.11733333021402359 loss:  2.0794413089752197
# 2  bits results:  acc:  0.11733333021402359 loss:  2.0794413089752197
# 3  bits results:  acc:  0.11733333021402359 loss:  2.0794413089752197
# 4  bits results:  acc:  0.11599999666213989 loss:  6.910543441772461
# 5  bits results:  acc:  0.19066666066646576 loss:  7.691606044769287
# 6  bits results:  acc:  0.7213333249092102 loss:  0.641737699508667
# 7  bits results:  acc:  0.8519999980926514 loss:  0.4112684726715088
# 8  bits results:  acc:  0.8893333077430725 loss:  0.33874770998954773
# 9  bits results:  acc:  0.8853333592414856 loss:  0.3419257402420044
# 10  bits results:  acc:  0.890666663646698 loss:  0.31690266728401184
# 11  bits results:  acc:  0.8840000033378601 loss:  0.31711503863334656
# 12  bits results:  acc:  0.8880000114440918 loss:  0.315687894821167
# 13  bits results:  acc:  0.8826666474342346 loss:  0.31667792797088623
# 14  bits results:  acc:  0.8853333592414856 loss:  0.3154712915420532
# Activation integer part
# 0  bits results:  acc:  0.11599999666213989 loss:  2.2177491188049316
# 1  bits results:  acc:  0.3440000116825104 loss:  1.8111580610275269
# 2  bits results:  acc:  0.7160000205039978 loss:  0.856968104839325
# 3  bits results:  acc:  0.8546666502952576 loss:  0.40941333770751953
# 4  bits results:  acc:  0.8826666474342346 loss:  0.31773841381073
# 5  bits results:  acc:  0.8853333592414856 loss:  0.315643310546875
# 6  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 7  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 8  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 9  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 10  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 11  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 12  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 13  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 14  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# Weights integer part
# 0  bits results:  acc:  0.5040000081062317 loss:  2.6318600177764893
# 1  bits results:  acc:  0.7720000147819519 loss:  0.8004140853881836
# 2  bits results:  acc:  0.871999979019165 loss:  0.3412128984928131
# 3  bits results:  acc:  0.8893333077430725 loss:  0.3005180358886719
# 4  bits results:  acc:  0.890666663646698 loss:  0.3091023862361908
# 5  bits results:  acc:  0.8853333592414856 loss:  0.3154723644256592
# 6  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 7  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 8  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 9  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 10  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 11  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 12  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 13  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188
# 14  bits results:  acc:  0.8853333592414856 loss:  0.3156031668186188

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; a) Number of bits analysis

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; b) Used Config

# %% [markdown]
# En base a lo anterior parece prudente usar 11 bits de fraccion junto a 4 bits de parte entera tanto para pesos como activaciones, los resultados bajo esa configuracion se pueden obtener usando la funcion CheckAccurucyAndLoss()

# %%
CheckAccuracyAndLoss('AlexNet', test_set, wgt_dir, act_frac_size = 11, act_int_size = 4, wgt_frac_size = 11, wgt_int_size = 4, 
                    input_shape = (227,227,3), output_shape = 8, batch_size = test_batch_size);
# Out:
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active dentro de la red Alexnet en capa 0 False
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active dentro de la red Alexnet en capa 1 False
# aging_active dentro de la red Alexnet en capa 2 False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active dentro de la red Alexnet en capa 1 False
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# estoy en WeightQuantization
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# 75/75 [==============================] - 15s 185ms/step - loss: 0.3125 - accuracy: 0.8907
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# cantidad de ekementos 10
# (10, 55, 55, 96)
# <class 'numpy.ndarray'>
# cantidad de ekementos 2904000
# np.isnan input [False False False ... False False False]
# np.isnan output [False False False ... False False False]
#            inp    out
# 0        False  False
# 1        False  False
# 2        False  False
# 3        False  False
# 4        False  False
# ...        ...    ...
# 2903995  False  False
# 2903996  False  False
# 2903997  False  False
# 2903998  False  False
# 2903999  False  False
#
# [2904000 rows x 2 columns]
# inp    0
# out    0
# dtype: int64

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  c) Activation Stats

# %% [markdown]
# Por otro lado, para la configuracion anterior, veremos el valor medio,maximo,minimo y el ratio de saturacion tanto de las activaciones procesadas dentro de la unidad matricial de multiplicacion como de las almacenadas en el buffer. Nota: el ultimo parametro indica el numero de iteraciones que se deben realizar hasta agotar el dataset, se obtiene como numero de imagenes del dataset dividido en el batch size.

# %%
ActivationStats(AlexNet,test_set,11,4,24)
# Out:
# mean value (MMU): -0.18011768
# mean value (Buffer): 0.13878344
# maximum (MMU): 45.118935
# minimum (MMU): -76.98705
# maximum (Buffer): 44.172142
# minimum (Buffer): -3.4607625
# saturation ratio (MMU): 0.002840600757529724
# saturation ratio (Buffer): 7.009283344612763e-06

# %% [markdown]
# # 3) Buffer Simulation

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; a) Baseline

# %% [markdown]
# Ahora para el Baseline simularemos el comportamiento de 1 buffer durante la inferencia de 3 imagenes (solo 3 como ejemplo), la red se crea ahora activando la cuantizacion pero no el envejecimiento. LI y AI son los definidos en el item 2) Stats

# %%
train_batchSize = test_batchSize = 1
_,_,test_set = GetDatasets('colorectal_histology',(80,5,15),(227,227), 8, train_batchSize, test_batchSize)

#Obtain quantized network with the used configf
QAlexNet  = GetNeuralNetworkModel('AlexNet',(227,227,3),8, quantization = True, aging_active=False,
                                  word_size = 16, frac_size = 11)
loss = tf.keras.losses.CategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
metrics = ['accuracy']
QAlexNet.compile(optimizer=optimizer, loss=loss, metrics=metrics)
QAlexNet.load_weights(wgt_dir).expect_partial()
#Quantize the weights of the network too, with used config
WeightQuantization(model = QAlexNet, frac_bits = 11, int_bits = 4)

#Lista de capas acorde a 2.b
LI = [0,3,9,11,17,19,25,31,37,40,45,50]
AI = [2,8,10,16,18,24,30,36,38,44,49,53]
Buffer,ciclos =  buffer_simulation(QAlexNet, test_set, integer_bits = 4, fractional_bits = 11, samples = 3, start_from = 0,
                                  bit_invertion = False, bit_shifting = False, CNN_gating = False,
                                  buffer_size = 2*290400, write_mode ='default', save_results = False,
                                  results_dir = 'Data/Stats/AlexNet/Colorectal Dataset/CNN-Gated/',
                                  layer_indexes = LI , activation_indixes = AI)
# Out:
# buffer sections:  [0, 36300, 72600, 108900, 145200, 181500, 217800, 254100, 290400]
# Simulation Started, time: 10:20:35 cycles:  0 offset:  0
# ---------------------------------------------------------------------------
# CudaSupportError                          Traceback (most recent call last)
# <ipython-input-16-7a22e2afb109> in <module>
#      16 LI = [0,3,9,11,17,19,25,31,37,40,45,50]
#      17 AI = [2,8,10,16,18,24,30,36,38,44,49,53]
# ---> 18 Buffer,ciclos =  buffer_simulation(QAlexNet, test_set, integer_bits = 4, fractional_bits = 11, samples = 3, start_from = 0,
#      19                                   bit_invertion = False, bit_shifting = False, CNN_gating = False,
#      20                                   buffer_size = 2*290400, write_mode ='default', save_results = False,
#
# ~\Desktop\CNN_Gating\Simulation.py in buffer_simulation(network, dataset, samples, integer_bits, fractional_bits, bit_invertion, bit_shifting, write_mode, CNN_gating, buffer_size, start_from, results_dir, layer_indexes, activation_indixes, save_results, network_type)
#     483                 if network_type == 'MobileNet':
#     484                         activacions[-1] = activacions[-1].reshape((1,1,1,activacions[-1].size))
# --> 485                 cycles += simulate_one_image(layers,activacions,config, buffer, index%2)
#     486                 buffer['LowCyclesCount'] = cycles -  buffer['HighCyclesCount']  -  buffer['OffCyclesCount']
#     487                 # Update duty strategies
#
# ~\Desktop\CNN_Gating\Simulation.py in simulate_one_image(layers, activations, config, buffer, first_buffer)
#     415         for index,layer in enumerate(layers):
#     416                 tmp = cycles
# --> 417                 cycles += handle_layer(buffer,layer,activations[index],(first_buffer+index)%2)
#     418                 if DEBUG: print('layer processed in: ',cycles-tmp,' cycles')
#     419         return cycles
#
# ~\Desktop\CNN_Gating\Simulation.py in handle_layer(buffer, layer, layer_outputs, out_buffer_id)
#     407                 else:
#     408                         if DEBUG: print('--now processing CPULayer', layer.name)
# --> 409                         return sim_CPULayer(buffer, layer, layer_outputs,out_buffer_id)
#     410         #########Simulation layer by layer####################################################################
#     411         cycles = 0
#
# ~\Desktop\CNN_Gating\Simulation.py in sim_CPULayer(buffer, layer, layer_outputs, write_buffer_id)
#     334                         return int(np.ceil(layer_outputs.size/acts_per_cycle))
#     335                 else:
# --> 336                         cycles = write_Loop(buffer,layer,activations,0,params)
#     337                         if DEBUG: print('----elapsed layer simulation time: ',str(datetime.now() - t0).split('.')[0])
#     338                         return cycles
#
# ~\Desktop\CNN_Gating\Simulation.py in write_Loop(buffer, layer, activations, manual_offset, params)
#     188                 #Update stats after the initial delay
#     189                 cycles = params['Initial Delay']
# --> 190                 update_high_cycle_count[blockspergrid, threadsperblock](data,high_cycles_count,params['Initial Delay'])
#     191                 #Acceleration of GPU Memory Transfer using small representation
#     192                 tmp_counter = 0
#
# ~\anaconda3\envs\env_first\lib\site-packages\numba\cuda\compiler.py in __call__(self, *args)
#     767
#     768     def __call__(self, *args):
# --> 769         return self.dispatcher.call(args, self.griddim, self.blockdim,
#     770                                     self.stream, self.sharedmem)
#     771
#
# ~\anaconda3\envs\env_first\lib\site-packages\numba\cuda\compiler.py in call(self, args, griddim, blockdim, stream, sharedmem)
#     859         argtypes = tuple(
#     860             [self.typingctx.resolve_argument_type(a) for a in args])
# --> 861         kernel = self.compile(argtypes)
#     862         kernel.launch(args, griddim, blockdim, stream, sharedmem)
#     863
#
# ~\anaconda3\envs\env_first\lib\site-packages\numba\cuda\compiler.py in compile(self, sig)
#     920         argtypes, return_type = sigutils.normalize_signature(sig)
#     921         assert return_type is None or return_type == types.none
# --> 922         cc = get_current_device().compute_capability
#     923         if self.specialized:
#     924             return self.definition
#
# ~\anaconda3\envs\env_first\lib\site-packages\numba\cuda\api.py in get_current_device()
#     373 def get_current_device():
#     374     "Get current device associated with the current thread"
# --> 375     return current_context().device
#     376
#     377
#
# ~\anaconda3\envs\env_first\lib\site-packages\numba\cuda\cudadrv\devices.py in get_context(devnum)
#     210     return the CUDA context.
#     211     """
# --> 212     return _runtime.get_or_create_context(devnum)
#     213
#     214
#
# ~\anaconda3\envs\env_first\lib\site-packages\numba\cuda\cudadrv\devices.py in get_or_create_context(self, devnum)
#     136             attached_ctx = self._get_attached_context()
#     137             if attached_ctx is None:
# --> 138                 return self._get_or_create_context_uncached(devnum)
#     139             else:
#     140                 return attached_ctx
#
# ~\anaconda3\envs\env_first\lib\site-packages\numba\cuda\cudadrv\devices.py in _get_or_create_context_uncached(self, devnum)
#     149             # Try to get the active context in the CUDA stack or
#     150             # activate GPU-0 with the primary context
# --> 151             with driver.get_active_context() as ac:
#     152                 if not ac:
#     153                     return self._activate_context_for(0)
#
# ~\anaconda3\envs\env_first\lib\site-packages\numba\cuda\cudadrv\driver.py in __enter__(self)
#     393         else:
#     394             hctx = drvapi.cu_context(0)
# --> 395             driver.cuCtxGetCurrent(byref(hctx))
#     396             hctx = hctx if hctx.value else None
#     397
#
# ~\anaconda3\envs\env_first\lib\site-packages\numba\cuda\cudadrv\driver.py in __getattr__(self, fname)
#     283
#     284         if self.initialization_error is not None:
# --> 285             raise CudaSupportError("Error at driver init: \n%s:" %
#     286                                    self.initialization_error)
#     287
#
# CudaSupportError: Error at driver init:
#
# CUDA driver library cannot be found.
# If you are sure that a CUDA driver is installed,
# try setting environment variable NUMBA_CUDA_DRIVER
# with the file path of the CUDA driver shared library.
# :

# %% [markdown]
# El resultado es un diccionario como el siguiente donde por ejemplo Data contiene el ultimo valor registrado para cada celda de memoria.

# %%
Buffer

# %%
ciclos

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; b) CNN-Gated, buffer 2 MB

# %% [markdown]
# Se puede hacer lo mismo para distintas configuraciones de buffer y estrategias usadas

# %%
#train_batchSize = test_batchSize = 1
#_,_,test_set = GetDatasets('colorectal_histology',(80,5,15),(227,227), 8, train_batchSize, test_batchSize)
#
##Obtain quantized network with the used configf
#QAlexNet  = GetNeuralNetworkModel('AlexNet',(227,227,3),8, quantization = True, aging_active=False,
#                                  word_size = 16, frac_size = 11)
#loss = tf.keras.losses.CategoricalCrossentropy()
#optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
#metrics = ['accuracy']
#QAlexNet.compile(optimizer=optimizer, loss=loss, metrics=metrics)
#QAlexNet.load_weights(wgtDir).expect_partial()
##Quantize the weights of the network too, with used config
#WeightQuantization(model = QAlexNet, frac_bits = 11, int_bits = 4)
#
##Lista de capas acorde a 2.b
#LI = [0,3,9,11,17,19,25,31,37,40,45,50]
#AI = [2,8,10,16,18,24,30,36,38,44,49,53]
#Buffer,ciclos =  buffer_simulation(QAlexNet, test_set, integer_bits = 4, fractional_bits = 11, samples = 150, start_from = 0,
#                                  bit_invertion = False, bit_shifting = False, CNN_gating = True,
#                                  buffer_size = 2*1024*1024, write_mode ='default', save_results = False,
#                                  results_dir = 'Data/Stats/AlexNet/Colorectal Dataset/CNN-Gated/',
#                                  layer_indexes = LI , activation_indixes = AI)

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; c) CNN-Gated, buffer ajustado a capa mas grande

# %%
#train_batchSize = test_batchSize = 1
#_,_,test_set = GetDatasets('colorectal_histology',(80,5,15),(227,227), 8, train_batchSize, test_batchSize)
#
##Obtain quantized network with the used configf
#QAlexNet  = GetNeuralNetworkModel('AlexNet',(227,227,3),8, quantization = True, aging_active=False,
#                                  word_size = 16, frac_size = 11)
#loss = tf.keras.losses.CategoricalCrossentropy()
#optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
#metrics = ['accuracy']
#QAlexNet.compile(optimizer=optimizer, loss=loss, metrics=metrics)
#QAlexNet.load_weights(wgtDir).expect_partial()
##Quantize the weights of the network too, with used config
#WeightQuantization(model = QAlexNet, frac_bits = 11, int_bits = 4)
#
#
#LI = [0,3,9,11,17,19,25,31,37,40,45,50]
#AI = [2,8,10,16,18,24,30,36,38,44,49,53]
#Buffer,ciclos =  buffer_simulation(QAlexNet, test_set, integer_bits = 4, fractional_bits = 11, samples = 150, start_from = 0,
#                                  bit_invertion = False, bit_shifting = False, CNN_gating = True,
#                                  buffer_size = 2*290400, write_mode ='default', save_results = False,
#                                  results_dir = 'Data/Stats/AlexNet/Colorectal Dataset/CNN-Gated/',
#                                  layer_indexes = LI , activation_indixes = AI)

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; ... d) para cargar los datos:

# %% [markdown]
# tambien puedes cargar los datos desde la ruta que especificaste para guardar los resultados (parametro results_dir + save_results de buffer_simulation())

# %%
#Buffer  = load_obj('Data/Stats/AlexNet/Colorectal Dataset/CNN-Gated/Full Buffer/Buffer')
#ciclos  = load_obj('Data/Stats/AlexNet/Colorectal Dataset/CNN-Gated/Full Buffer/cycles')

# %% [markdown]
# # 4) Error Injection

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; a) Measuring effect of faults in activations

# %% [markdown]
# por ultimo con este bloque vemos como se comporta el accuracy y loss frente a el envejecimiento de celdas.

# %%
from copy import deepcopy
from Stats import CheckAccuracyAndLoss
from Simulation import save_obj, load_obj
from datetime import datetime
import itertools
from Nets_original  import GetNeuralNetworkModel

#trainBatchSize = testBatchSize = 16 modificado por yamilka abajo
trainBatchSize = testBatchSize = 1
_,_,test_dataset = GetDatasets('colorectal_histology',(80,5,15),(227,227), 8, trainBatchSize, testBatchSize)


# Porciones del buffer con fallos a probar
Accs     = {0.00001:[],0.00005:[],0.0001:[]}
Loss     = {0.00001:[],0.00005:[],0.0001:[]}

# Tamaño del buffer (en bits)
network_size   = 290400*16
# Numero de muestras de distintas configuraciones de fallos a testear por cada valor de Accs/Loss
num_of_samples = 1
for Enumber in Accs:
    print(type(Accs))
    print(Enumber)
    n_bits_fails = np.ceil(Enumber*network_size).astype(int)    #numero de bits con fallos
    errors       = np.random.randint(0,2,n_bits_fails)          #tipo de fallos (0 o 1)
    # crear una representacion del buffer x indica celda inafectada, 1 celda con valor 1 permanente y 0 celda con valor 0 perm.
    buffer       = np.array(['x']*(network_size-n_bits_fails))  
    buffer       = np.concatenate([buffer,errors])
    print('tamaño del',len(buffer))
    
    for index in range(0,num_of_samples):
        np.random.shuffle(buffer)  # crear un orden aleatorio de los errores en el buffer
        # en las siguientes 4 lineas se obtienen las direcciones de los errores y los tipos de error
        #print(buffer)
        address_with_errors = np.reshape(buffer,(-1,16))
       # print(address_with_errors)
        #print(address_with_errors)
        address_with_errors = ["".join(i) for i in address_with_errors]
        #print(address_with_errors)
        #print(address_with_errors)
        error_mask = [y for x,y in enumerate(address_with_errors) if y.count('x') < 16]
        #print(error_mask)
        locs       = [x for x,y in enumerate(address_with_errors) if y.count('x') < 16]
        print('loooo',len(locs))
        print(len(error_mask))
        del address_with_errors
        #ahora se obtiene el loss y acc para esta configuracion.
        loss,acc   = CheckAccuracyAndLoss('AlexNet', test_dataset, wgt_dir, output_shape=8, input_shape = (227,227,3),
                                            act_frac_size = 11, act_int_size = 4, wgt_frac_size = 11, wgt_int_size = 4,
                                            batch_size=testBatchSize, verbose = 0, aging_active = True, weights_faults = False,
                                            faulty_addresses = locs, masked_faults = error_mask)
        print(loss)
        print(acc)
        Accs[Enumber].append(acc)
        Loss[Enumber].append(loss)
    print(str(Enumber)+' completada: ', datetime.now().strftime("%H:%M:%S"))
    #save_obj(Accs,'Data/Errors/AlexNet/Colorectal Dataset/Uniform distribution/Accs')
    #save_obj(Loss,'Data/Errors/AlexNet/Colorectal Dataset/Uniform distribution/Loss')
# Out:
# <class 'dict'>
# 1e-05
# tamaño del 4646400
# loooo 47
# 47
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active dentro de la red Alexnet en capa 0 False
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active dentro de la red Alexnet en capa 1 False
# aging_active dentro de la red Alexnet en capa 2 False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active dentro de la red Alexnet en capa 1 False
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# estoy en WeightQuantization
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# cantidad de ekementos 1
# (1, 55, 55, 96)
# <class 'numpy.ndarray'>
# cantidad de ekementos 290400
# np.isnan input [False False False ... False False False]
# np.isnan output [False False False ... False False False]
#           inp    out
# 0       False  False
# 1       False  False
# 2       False  False
# 3       False  False
# 4       False  False
# ...       ...    ...
# 290395  False  False
# 290396  False  False
# 290397  False  False
# 290398  False  False
# 290399  False  False
#
# [290400 rows x 2 columns]
# inp    0
# out    0
# dtype: int64
# 0.3124760091304779
# 0.890666663646698
# 1e-05 completada:  20:53:06
# <class 'dict'>
# 5e-05
# tamaño del 4646400
# loooo 233
# 233
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active dentro de la red Alexnet en capa 0 False
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active dentro de la red Alexnet en capa 1 False
# aging_active dentro de la red Alexnet en capa 2 False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active dentro de la red Alexnet en capa 1 False
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# estoy en WeightQuantization
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# cantidad de ekementos 1
# (1, 55, 55, 96)
# <class 'numpy.ndarray'>
# cantidad de ekementos 290400
# np.isnan input [False False False ... False False False]
# np.isnan output [False False False ... False False False]
#           inp    out
# 0       False  False
# 1       False  False
# 2       False  False
# 3       False  False
# 4       False  False
# ...       ...    ...
# 290395  False  False
# 290396  False  False
# 290397  False  False
# 290398  False  False
# 290399  False  False
#
# [290400 rows x 2 columns]
# inp    0
# out    0
# dtype: int64
# 0.3124760091304779
# 0.890666663646698
# 5e-05 completada:  20:53:43
# <class 'dict'>
# 0.0001
# tamaño del 4646400
# loooo 464
# 464
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active dentro de la red Alexnet en capa 0 False
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active dentro de la red Alexnet en capa 1 False
# aging_active dentro de la red Alexnet en capa 2 False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active dentro de la red Alexnet en capa 1 False
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# dentro de includin Aging False
# dentro de GenerateAddressList
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# dentro de DecodeMask
# aging_active dentro de aging_argiments False
# dentro de Aging
# aging_active en AddCustomLayers False
# aging_active en AddCustomLayers False
# estoy en WeightQuantization
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# dentro de Aging
# cantidad de ekementos 1
# (1, 55, 55, 96)
# <class 'numpy.ndarray'>
# cantidad de ekementos 290400
# np.isnan input [False False False ... False False False]
# np.isnan output [False False False ... False False False]
#           inp    out
# 0       False  False
# 1       False  False
# 2       False  False
# 3       False  False
# 4       False  False
# ...       ...    ...
# 290395  False  False
# 290396  False  False
# 290397  False  False
# 290398  False  False
# 290399  False  False
#
# [290400 rows x 2 columns]
# inp    0
# out    0
# dtype: int64
# 0.3124760091304779
# 0.890666663646698
# 0.0001 completada:  20:54:21

# %% [markdown]
# El resultado es un diccionario con accuracy y loss para cada muestra, por ejemplo, el caso de 0.0001 del buffer con fallos la accuracy ronda entre el 71 y 76% en los 10 casos aleatorios probados.

# %%
Accs
# Out:
# {1e-05: [], 5e-05: [], 0.0001: []}

# %%
Loss

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; a) Measuring effect of faults in weights

# %% [markdown]
# Puedes hacer lo mismo para fallos en los pesos

# %%
from copy import deepcopy
from Stats import CheckAccuracyAndLoss
from Simulation import save_obj, load_obj
from datetime import datetime
import itertools


trainBatchSize = testBatchSize = 16
_,_,test_dataset = GetDatasets('colorectal_histology',(80,5,15),(227,227), 8, trainBatchSize, testBatchSize)


# Porciones del buffer con fallos a probar
Accs     = {0.00001:[],0.00005:[],0.0001:[]}
Loss     = {0.00001:[],0.00005:[],0.0001:[]}

# Tamaño del buffer (en bits)
network_size   = 885120*16
num_of_samples = 200
for Enumber in Accs:
    n_bits_fails = np.ceil(Enumber*290400).astype(int)
    errors       = np.random.randint(0,2,n_bits_fails)
    buffer       = np.array(['x']*(network_size-n_bits_fails))
    buffer       = np.concatenate([buffer,errors])
    for index in range(0,num_of_samples):
        np.random.shuffle(buffer)
        address_with_errors = np.reshape(buffer,(-1,16))
        address_with_errors = ["".join(i) for i in address_with_errors]
        error_mask = [y for x,y in enumerate(address_with_errors) if y.count('x') < 16]
        locs       = [x for x,y in enumerate(address_with_errors) if y.count('x') < 16]
        del address_with_errors
        loss,acc   = CheckAccuracyAndLoss('AlexNet', test_dataset, wgt_dir, output_shape=8, input_shape = (227,227,3),
                                            act_frac_size = 11, act_int_size = 4, wgt_frac_size = 11, wgt_int_size = 4,
                                            batch_size=testBatchSize, verbose = 0, aging_active = False, weights_faults = True,
                                            faulty_addresses = locs, masked_faults = error_mask)
        print(acc)
        print(loss)
        print(index,' completados: ', datetime.now().strftime("%H:%M:%S"))
        Accs[Enumber].append(acc)
        Loss[Enumber].append(loss)
    print(str(Enumber)+' completada: ', datetime.now().strftime("%H:%M:%S"))
    #save_obj(Accs,'Data/Errors/AlexNet/Colorectal Dataset/Uniform distribution/weights Accs')
    #save_obj(Loss,'Data/Errors/AlexNet/Colorectal Dataset/Uniform distribution/weights Loss')
# Out:
# xxxxxxx0xxxxxxxx
# xxxxxxxxxxx0xxxx
# xxxxxxx1xxxxxxxx
# xxxxxxx0xxxxxxxx
# xxxxxxxxxxx0xxxx
# xxxxxxx1xxxxxxxx
# 0.890666663646698
# [289187, 503148, 542555]
# 0  completados:  12:03:04
# xxxx0xxxxxxxxxxx
# xxx0xxxxxxxxxxxx
# xxxx1xxxxxxxxxxx
# xxxx0xxxxxxxxxxx
# xxx0xxxxxxxxxxxx
# xxxx1xxxxxxxxxxx
# 0.890666663646698
# [108713, 128139, 691189]
# 1  completados:  12:03:28
# xxxxxxxxxx0xxxxx
# 0xxxxxxxxxxxxxxx
# xxxxxxxxxxx1xxxx
# xxxxxxxxxx0xxxxx
# 0xxxxxxxxxxxxxxx
# xxxxxxxxxxx1xxxx
# 0.890666663646698
# [40005, 342208, 640405]
# 2  completados:  12:03:50
# xxxxxxxxxxxxxx1x
# xxxxx0xxxxxxxxxx
# xxxxx0xxxxxxxxxx
# xxxxxxxxxxxxxx1x
# xxxxx0xxxxxxxxxx
# xxxxx0xxxxxxxxxx
# 0.890666663646698
# [108143, 132892, 392936]
# 3  completados:  12:04:09
# xxxxxxxxxxxx0xxx
# 1xxxxxxxxxxxxxxx
# xxxxxxxx0xxxxxxx
# xxxxxxxxxxxx0xxx
# 1xxxxxxxxxxxxxxx
# xxxxxxxx0xxxxxxx
# 0.890666663646698
# [73137, 165204, 396007]
# 4  completados:  12:04:27
# xxxxxxx0xxxxxxxx
# xxxxxxxxxxxxx1xx
# xxxxxxxxxxxx0xxx
# xxxxxxx0xxxxxxxx
# xxxxxxxxxxxxx1xx
# xxxxxxxxxxxx0xxx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-da180de559fb> in <module>
#      29         locs       = [x for x,y in enumerate(address_with_errors) if y.count('x') < 16]
#      30         del address_with_errors
# ---> 31         loss,acc   = CheckAccuracyAndLoss('AlexNet', test_dataset, wgt_dir, output_shape=8, input_shape = (227,227,3),
#      32                                             act_frac_size = 11, act_int_size = 4, wgt_frac_size = 11, wgt_int_size = 4,
#      33                                             batch_size=testBatchSize, verbose = 0, aging_active = False, weights_faults = True,
#
# ~\Desktop\CNN_Gating\Stats.py in CheckAccuracyAndLoss(architecture, test_dataset, wgt_dir, act_frac_size, act_int_size, wgt_frac_size, wgt_int_size, input_shape, output_shape, faulty_addresses, masked_faults, aging_active, batch_size, verbose, weights_faults)
#     121         else:
#     122                 qNet.compile(optimizer=optimizer, loss=loss, metrics='accuracy')
# --> 123                 loss,acc  = qNet.evaluate(test_dataset,verbose=verbose)
#     124                 outputs = (loss,acc)
#     125         # Cleaning Memory
#
# ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1487             with trace.Trace('test', step_num=step, _r=1):
#    1488               callbacks.on_test_batch_begin(step)
# -> 1489               tmp_logs = self.test_function(iterator)
#    1490               if data_handler.should_sync:
#    1491                 context.async_wait()
#
# ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3021       (graph_function,
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#
# ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958         and executing_eagerly):
#    1959       # No tape is watching; skip to running the function.
# -> 1960       return self._build_call_outputs(self._inference_function.call(
#    1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~\anaconda3\envs\env_first\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59
# ---> 60     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                         inputs, attrs, num_outputs)
#      62   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
